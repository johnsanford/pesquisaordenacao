# %% [markdown]
# <a href="https://colab.research.google.com/github/johnsanford/pesquisaordenacao/blob/master/ShellSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def createList(size):
    lyst = []
    for x in range(size):
        lyst.append(random.randrange(100000))
    return lyst
unsortedList = createList(1000)
print(unsortedList)

def createList2(size):
    lyst = []
    for x in range(size):
        lyst.append(random.randrange(100000))
    return lyst
unsortedList = createList(10000)
print(unsortedList)

def createList3(size):
    lyst = []
    for x in range(size):
        lyst.append(random.randrange(100000))
    return lyst
unsortedList = createList(30000)
print(unsortedList)

def createList4(size):
    lyst = []
    for x in range(size):
        lyst.append(random.randrange(100000))
    return lyst
unsortedList = createList(60000)
print(unsortedList)


from random import randint
import timeit
import matplotlib as mpl
import matplotlib.pyplot as plt

def shellSort(alist):
    sublistcount = len(alist)//2
    while sublistcount > 0:
      for start_position in range(sublistcount):
        gap_InsertionSort(alist, start_position, sublistcount)

      print("After increments of size",sublistcount, "The list is",nlist)

      sublistcount = sublistcount // 2

def gap_InsertionSort(unsortedList,start,gap):
    for i in range(start+gap,len(unsortedList),gap):

        current_value = unsortedList[i]
        position = i

        while position>=gap and unsortedList[position-gap]>current_value:
            unsortedList[position]=unsortedList[position-gap]
            position = position-gap

        unsortedList[position]=current_value

def gap_InsertionSort(unsortedList2,start,gap):
    for i in range(start+gap,len(unsortedList2),gap):

        current_value = unsortedList2[i]
        position = i

        while position>=gap and unsortedList2[position-gap]>current_value:
            unsortedList2[position]=unsortedList2[position-gap]
            position = position-gap

        unsortedList2[position]=current_value
        
def gap_InsertionSort(unsortedList3,start,gap):
    for i in range(start+gap,len(unsortedList3),gap):

        current_value = unsortedList3[i]
        position = i

        while position>=gap and unsortedList3[position-gap]>current_value:
            unsortedList3[position]=unsortedList3[position-gap]
            position = position-gap

        unsortedList3[position]=current_value
        
def gap_InsertionSort(unsortedList4,start,gap):
    for i in range(start+gap,len(unsortedList4),gap):

        current_value = unsortedList4[i]
        position = i

        while position>=gap and unsortedList4[position-gap]>current_value:
            unsortedList4[position]=unsortedList4[position-gap]
            position = position-gap

        unsortedList4[position]=current_value        

shellSort(unsortedList)
shellSort(unsortedList2)
shellSort(unsortedList3)
shellSort(unsortedList4)
print(unsortedList)
print(unsortedList2)
print(unsortedList3)
print(unsortedList4)

mpl.use('Agg')
  
def desenhaGrafico(x,y,y2,xl = "Entradas", yl = "Saídas"):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111)
    ax.plot(x,y, label = "1000")
    ax.plot(x,y2, label = "10000")
    ax.plot(x,y3, label = "30000")
    ax.plot(x,y4, label = "60000")
    ax.legend(bbox_to_anchor=(1, 1),bbox_transform=plt.gcf().transFigure)
    plt.ylabel(yl)
    plt.xlabel(xl)
    fig.savefig('ShellSort.png')
   
x2 = [1,2,3,4]
y = []
y2= []
y3= []
y4= []
  
for i in range(4):
    y.append(timeit.timeit("createList({})".format(x2[i]),setup="from __main__ import createList",number=1))  
    y2.append(timeit.timeit("createList2({})".format(x2[i]),setup="from __main__ import createList2",number=1)) 
    y3.append(timeit.timeit("createList3({})".format(x2[i]),setup="from __main__ import createList3",number=1)) 
    y4.append(timeit.timeit("createList4({})".format(x2[i]),setup="from __main__ import createList4",number=1)) 
  
desenhaGrafico(x2,y,y2)
# Out:
# [16875, 33935, 86008, 96194, 71612, 34873, 7727, 28712, 75401, 21053, 4057, 16442, 37239, 35359, 53842, 10465, 15908, 49433, 33322, 74745, 67436, 85219, 36009, 13165, 91037, 35838, 27324, 48476, 16578, 29304, 59505, 81046, 99982, 49937, 81773, 55774, 28862, 50947, 37322, 19539, 7055, 87811, 94691, 29984, 92481, 61189, 10117, 7014, 86373, 33956, 83210, 82844, 96365, 55076, 88285, 27653, 6015, 20243, 29028, 72573, 61126, 12176, 55018, 75836, 482, 66330, 32430, 1091, 56116, 24479, 1139, 68021, 79845, 60384, 49077, 84477, 98828, 8083, 77781, 74522, 95816, 42773, 23707, 18119, 6724, 42300, 59492, 73084, 51978, 73252, 95511, 69188, 27841, 16465, 8285, 87875, 3764, 66468, 93486, 65007, 10969, 8253, 53703, 75976, 97146, 22496, 62817, 86280, 82106, 28640, 53825, 69366, 36375, 26530, 63520, 48152, 32879, 41834, 89632, 4826, 49163, 66499, 48712, 79222, 12630, 90014, 20784, 12415, 31535, 85433, 48393, 21336, 89472, 38449, 24033, 93746, 7666, 65614, 76539, 23577, 63669, 73976, 35651, 94117, 43855
# ...
